# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

uri = "mongodb+srv://jeevaranand6_db_user:Jawahar1603@cluster0.bxoc1xe.mongodb.net/?appName=Cluster0"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
pip install --upgrade pymongo
# Out:
# Requirement already satisfied: pymongo in d:\Study Materials\Python\Learning\ML Projects\cvenv\Lib\site-packages (4.7.0)
# Collecting pymongo
#   Using cached pymongo-4.16.0-cp314-cp314-win_amd64.whl.metadata (10.0 kB)
# Requirement already satisfied: dnspython<3.0.0,>=2.6.1 in d:\Study Materials\Python\Learning\ML Projects\cvenv\Lib\site-packages (from pymongo) (2.8.0)
# Using cached pymongo-4.16.0-cp314-cp314-win_amd64.whl (1.0 MB)
# Installing collected packages: pymongo
#   Attempting uninstall: pymongo
#     Found existing installation: pymongo 4.7.0
#     Uninstalling pymongo-4.7.0:
#       Successfully uninstalled pymongo-4.7.0
# Successfully installed pymongo-4.16.0
# Note: you may need to restart the kernel to use updated packages.

# %%
mongosh "mongodb+srv://<cluster-url>" --username <user>
# Out:
#   Cell In[4], line 1
#     python -c "import ssl; print(ssl.OPENSSL_VERSION)"
#               ^
# SyntaxError: invalid syntax
